# %% [markdown]
# # **AMERICAN INTERNATIONAL UNIVERSITY-BANGLADESH**
# ---
# ## **PROGRAMMING IN PYTHON**
# **Section:** C | **Semester:** Spring 25-26
# ### *Final Term Project*
#
# > #### **Air Quality Dynamics in Dhaka**
# > *A Data-Driven Analysis of Trends, Seasonality, and Pollution Extremes*
#
# **Project Members:**
# | Name | Student ID | GitHub Profile |
# | :--- | :---: | :--- |
# | Salman Sayeed | 22-49006-3 | [salman-sayeed](https://github.com/salman-sayeed) |
# | Kayjer Islam | 22-49005-3 | [kayjer-islam](https://github.com/Kayjer-Islam) |

# %% [markdown]
# ㅤㅤㅤㅤㅤ

# %%
#All imports will be heree
import os
from google.colab import userdata
import pandas as pd

# %%
#token dhorbina kayjer
try:
    os.environ['KAGGLE_API_TOKEN'] = userdata.get('KAGGLE_TOKEN')
    print("Kaggle token loaded successfully")
except:
    print("Token not found")
# Out:
# Kaggle token loaded successfully

# %%
# !kaggle datasets download -d shakil10945/dhaka-air-quality-2000-2025-synthetic-dataset --unzip

#data frame
df = pd.read_csv('dhaka_air_quality_2000_2025.csv')

#viewing 5
df.head()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shakil10945/dhaka-air-quality-2000-2025-synthetic-dataset
# License(s): CC0-1.0
# Downloading dhaka-air-quality-2000-2025-synthetic-dataset.zip to /content
# 100% 22.0M/22.0M [00:00<00:00, 80.9MB/s]
#               datetime         AQI      PM2.5        PM10         O3  \
# 0  2000-01-01 00:00:00  121.861086  44.200712   93.224101  20.586862
# 1  2000-01-01 01:00:00   99.598077  35.212704   78.893066  22.429471
# 2  2000-01-01 02:00:00  132.852834  48.575428  118.693959  37.838094
# 3  2000-01-01 03:00:00  154.588259  64.208516   86.427166  26.747684
# 4  2000-01-01 04:00:00  114.102260  41.112699   70.193382  33.192759
#
#          NO2        SO2        CO  Temperature   Humidity  Wind_Speed  \
# 0  15.391414  28.219932  1.049477    20.956667  71.272569    8.375675
# 1  26.824534  24.385188  0.943859    13.761031  42.616871   10.880553
# 2  33.403493  28.951413  0.887131    20.216907  59.169387   15.041183
# 3  12.137395  26.950990  0.793261    18.642574  62.756439    9.904413
# 4  25.313206  20.741976  1.059887    18.834718  56.369280   14.632070
#
#       Pressure
# 0  1011.742574
# 1  1010.949986
# 2  1012.065387
# 3  1010.162227
# 4  1007.067421
